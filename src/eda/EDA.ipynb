# %%
import wandb
import pandas as pd

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
df.head()
# Out:
# /opt/conda/envs/mlflow-6f02ff4842fbe0d4c84a3c2da9d0eede237ec11e/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /opt/conda/envs/mlflow-6f02ff4842fbe0d4c84a3c2da9d0eede237ec11e/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: Currently logged in as: anilavadhanula (anilavadhanula-none) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.3s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/workspaces/build-ml-pipeline-for-short-term-rental-prices/src/eda/wandb/run-20251208_022550-p8fqj7fo</code>
# Syncing run <strong><a href='https://wandb.ai/anilavadhanula-none/nyc_airbnb/runs/p8fqj7fo' target="_blank">golden-galaxy-3</a></strong> to <a href='https://wandb.ai/anilavadhanula-none/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/anilavadhanula-none/nyc_airbnb' target="_blank">https://wandb.ai/anilavadhanula-none/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/anilavadhanula-none/nyc_airbnb/runs/p8fqj7fo' target="_blank">https://wandb.ai/anilavadhanula-none/nyc_airbnb/runs/p8fqj7fo</a>
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaN
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20000 non-null  int64
#  1   name                            19993 non-null  object
#  2   host_id                         20000 non-null  int64
#  3   host_name                       19992 non-null  object
#  4   neighbourhood_group             20000 non-null  object
#  5   neighbourhood                   20000 non-null  object
#  6   latitude                        20000 non-null  float64
#  7   longitude                       20000 non-null  float64
#  8   room_type                       20000 non-null  object
#  9   price                           20000 non-null  int64
#  10  minimum_nights                  20000 non-null  int64
#  11  number_of_reviews               20000 non-null  int64
#  12  last_review                     15877 non-null  object
#  13  reviews_per_month               15877 non-null  float64
#  14  calculated_host_listings_count  20000 non-null  int64
#  15  availability_365                20000 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB
#                   id            name       host_id host_name  \
# count   2.000000e+04           19993  2.000000e+04     19992
# unique           NaN           19768           NaN      6517
# top              NaN  Hillside Hotel           NaN     David
# freq             NaN               7           NaN       170
# mean    1.892380e+07             NaN  6.746034e+07       NaN
# std     1.101223e+07             NaN  7.857936e+07       NaN
# min     2.539000e+03             NaN  2.571000e+03       NaN
# 25%     9.393540e+06             NaN  7.853718e+06       NaN
# 50%     1.952117e+07             NaN  3.111431e+07       NaN
# 75%     2.912936e+07             NaN  1.068426e+08       NaN
# max     3.648561e+07             NaN  2.742733e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                20000         20000  20000.000000  20000.000000
# unique                   5           217           NaN           NaN
# top              Manhattan  Williamsburg           NaN           NaN
# freq                  8774          1580           NaN           NaN
# mean                   NaN           NaN     40.728455    -73.952125
# std                    NaN           NaN      0.054755      0.046559
# min                    NaN           NaN     40.508730    -74.239140
# 25%                    NaN           NaN     40.689420    -73.983030
# 50%                    NaN           NaN     40.722730    -73.955640
# 75%                    NaN           NaN     40.762990    -73.936380
# max                    NaN           NaN     40.913060    -73.717950
#
#               room_type         price  minimum_nights  number_of_reviews  \
# count             20000  20000.000000    20000.000000       20000.000000
# unique                3           NaN             NaN                NaN
# top     Entire home/apt           NaN             NaN                NaN
# freq              10384           NaN             NaN                NaN
# mean                NaN    153.269050        6.992100          23.274100
# std                 NaN    243.325609       21.645449          44.927793
# min                 NaN      0.000000        1.000000           0.000000
# 25%                 NaN     69.000000        1.000000           1.000000
# 50%                 NaN    105.000000        2.000000           5.000000
# 75%                 NaN    175.000000        5.000000          23.000000
# max                 NaN  10000.000000     1250.000000         607.000000
#
#        last_review  reviews_per_month  calculated_host_listings_count  \
# count        15877       15877.000000                    20000.000000
# unique        1507                NaN                             NaN
# top     2019-06-23                NaN                             NaN
# freq           575                NaN                             NaN
# mean           NaN           1.377446                        6.955450
# std            NaN           1.683006                       32.433831
# min            NaN           0.010000                        1.000000
# 25%            NaN           0.190000                        1.000000
# 50%            NaN           0.720000                        1.000000
# 75%            NaN           2.010000                        2.000000
# max            NaN          27.950000                      327.000000
#
#         availability_365
# count       20000.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean          112.901200
# std           131.762226
# min             0.000000
# 25%             0.000000
# 50%            44.000000
# 75%           229.000000
# max           365.000000

# %%
import matplotlib.pyplot as plt

df['price'].hist(bins=50)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# last_review                       4123
# reviews_per_month                 4123
# host_name                            8
# name                                 7
# neighbourhood_group                  0
# neighbourhood                        0
# id                                   0
# host_id                              0
# longitude                            0
# latitude                             0
# room_type                            0
# price                                0
# number_of_reviews                    0
# minimum_nights                       0
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
# Drop outliers
min_price = 10
max_price = 350

idx = df['price'].between(min_price, max_price)
df = df[idx].copy()

# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

df.head()
# Out:
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaT
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8

# %%
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   1.900100e+04           18994  1.900100e+04     18993
# unique           NaN           18780           NaN      6307
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN               7           NaN       159
# mean    1.883041e+07             NaN  6.639459e+07       NaN
# min     2.539000e+03             NaN  2.571000e+03       NaN
# 25%     9.355498e+06             NaN  7.728754e+06       NaN
# 50%     1.938754e+07             NaN  3.048785e+07       NaN
# 75%     2.891952e+07             NaN  1.048354e+08       NaN
# max     3.648561e+07             NaN  2.742733e+08       NaN
# std     1.096986e+07             NaN  7.782663e+07       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                19001         19001  19001.000000  19001.000000
# unique                   5           215           NaN           NaN
# top               Brooklyn  Williamsburg           NaN           NaN
# freq                  8046          1526           NaN           NaN
# mean                   NaN           NaN     40.728063    -73.950827
# min                    NaN           NaN     40.508730    -74.239140
# 25%                    NaN           NaN     40.688820    -73.982050
# 50%                    NaN           NaN     40.721710    -73.954630
# 75%                    NaN           NaN     40.763210    -73.934490
# max                    NaN           NaN     40.913060    -73.717950
# std                    NaN           NaN      0.055389      0.046825
#
#               room_type         price  minimum_nights  number_of_reviews  \
# count             19001  19001.000000    19001.000000       19001.000000
# unique                3           NaN             NaN                NaN
# top     Entire home/apt           NaN             NaN                NaN
# freq               9522           NaN             NaN                NaN
# mean                NaN    122.340456        6.906900          23.797747
# min                 NaN     10.000000        1.000000           0.000000
# 25%                 NaN     66.000000        1.000000           1.000000
# 50%                 NaN    100.000000        2.000000           6.000000
# 75%                 NaN    160.000000        5.000000          24.000000
# max                 NaN    350.000000     1250.000000         607.000000
# std                 NaN     71.530346       21.456544          45.493455
#
#                           last_review  reviews_per_month  \
# count                           15243       15243.000000
# unique                            NaN                NaN
# top                               NaN                NaN
# freq                              NaN                NaN
# mean    2018-10-01 08:24:05.384766720           1.380928
# min               2011-05-12 00:00:00           0.010000
# 25%               2018-06-29 12:00:00           0.190000
# 50%               2019-05-19 00:00:00           0.720000
# 75%               2019-06-23 00:00:00           2.010000
# max               2019-07-08 00:00:00          27.950000
# std                               NaN           1.689988
#
#         calculated_host_listings_count  availability_365
# count                     19001.000000      19001.000000
# unique                             NaN               NaN
# top                                NaN               NaN
# freq                               NaN               NaN
# mean                          6.583811        109.725383
# min                           1.000000          0.000000
# 25%                           1.000000          0.000000
# 50%                           1.000000         39.000000
# 75%                           2.000000        219.000000
# max                         327.000000        365.000000
# std                          31.154750        130.599899

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">golden-galaxy-3</strong> at: <a href='https://wandb.ai/anilavadhanula-none/nyc_airbnb/runs/p8fqj7fo' target="_blank">https://wandb.ai/anilavadhanula-none/nyc_airbnb/runs/p8fqj7fo</a><br> View project at: <a href='https://wandb.ai/anilavadhanula-none/nyc_airbnb' target="_blank">https://wandb.ai/anilavadhanula-none/nyc_airbnb</a><br>Synced 6 W&B file(s), 0 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251208_022550-p8fqj7fo/logs</code>
